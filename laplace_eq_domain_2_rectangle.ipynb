# %%
import matplotlib.pyplot as plt
import matplotlib.tri as tri
import pandas as pd
import numpy as np

# plots a finite element mesh
def plot_fem_mesh(nodes_x, nodes_y, elements, linewidth: float = 0.2):
    # print(nodes_x)
    it = 0
    for element in elements:
        x = [nodes_x[element[0]], nodes_x[element[1]], nodes_x[element[2]]]
        y = [nodes_y[element[0]], nodes_y[element[1]], nodes_y[element[2]]]
        # print(x , y)
        plt.fill(x, y, edgecolor='black', linewidth = linewidth, fill=False)
        it += 1

# %% [markdown]
# <h1> Rectangle domain (small cell 0.05)

# %%
df_x_y = pd.read_csv("./domains/domain_2/mesh005/mesh_nodes.csv")

df_z = pd.read_csv("./output/domain_2/mesh005/Test_domain_2_rectangle_005_solution.csv")
df_elements = pd.read_csv("./domains/domain_2/mesh005/mesh_polygons.csv")
for element in df_elements.values:
    element -= 1;

triangulation = tri.Triangulation(df_x_y["x"].values, df_x_y["y"].values, triangles=df_elements.values)
plt.tricontourf(triangulation, df_z["sol"].values, levels = 15)
#show
#plot_fem_mesh(df_x_y["x"].values, df_x_y["y"].values, df_elements.values)

plt.colorbar()
plt.axis('equal')
plt.show()

# %% [markdown]
# <h1> Rectangle domain (small cell 0.05 another grid)

# %%
df_x_y = pd.read_csv("./domains/domain_2/mesh005_test/mesh_nodes.csv")
df_z = pd.read_csv("./output/domain_2/mesh005_test/Test_domain_2_rectangle_005_test_solution.csv")
df_elements = pd.read_csv("./domains/domain_2/mesh005_test/mesh_polygons.csv")
for element in df_elements.values:
    element -= 1;

triangulation = tri.Triangulation(df_x_y["x"].values, df_x_y["y"].values, triangles=df_elements.values)
plt.tricontourf(triangulation, df_z["sol"].values, levels = 25)
#show
#plot_fem_mesh(df_x_y["x"].values, df_x_y["y"].values, df_elements.values)

plt.colorbar()
plt.axis('equal')
plt.show()

# %% [markdown]
# <h1> Rectangle domain (small cell 0.01)

# %%
df_x_y = pd.read_csv("./domains/domain_2/mesh001/mesh_nodes.csv")
df_z = pd.read_csv("./output/domain_2/mesh001/Test_domain_2_rectangle_001_solution.csv")
df_elements = pd.read_csv("./domains/domain_2/mesh001/mesh_polygons.csv")
for element in df_elements.values:
    element -= 1;

triangulation = tri.Triangulation(df_x_y["x"].values, df_x_y["y"].values, triangles=df_elements.values)
plt.tricontourf(triangulation, df_z["sol"].values, levels = 35)
#show
#plot_fem_mesh(df_x_y["x"].values, df_x_y["y"].values, df_elements.values)

plt.colorbar()
plt.axis('equal')
plt.show()

# %% [markdown]
# <h1> Rectangle domain (small cell 0.0001)

# %%
df_x_y = pd.read_csv("./domains/domain_2/mesh0001/mesh_nodes.csv")
df_z = pd.read_csv("./output/domain_2/mesh0001/Test_domain_2_rectangle_0001_solution.csv")
df_elements = pd.read_csv("./domains/domain_2/mesh0001/mesh_polygons.csv")
for element in df_elements.values:
    element -= 1;

triangulation = tri.Triangulation(df_x_y["x"].values, df_x_y["y"].values, triangles=df_elements.values)
plt.tricontourf(triangulation, df_z["sol"].values, levels = 50)
#show
#plot_fem_mesh(df_x_y["x"].values, df_x_y["y"].values, df_elements.values)

plt.colorbar()
plt.axis('equal')
plt.show()

# %% [markdown]
# <h1> Rectangle domain (small cell 0.0008)

# %%
df_x_y = pd.read_csv("./domains/domain_2/mesh00008/mesh_nodes.csv")
df_z = pd.read_csv("./output/domain_2/mesh0008/Test_domain_2_rectangle_00008_solution.csv")
df_elements = pd.read_csv("./domains/domain_2/mesh00008/mesh_polygons.csv")
for element in df_elements.values:
    element -= 1;

triangulation = tri.Triangulation(df_x_y["x"].values, df_x_y["y"].values, triangles=df_elements.values)
plt.tricontourf(triangulation, df_z["sol"].values, levels = 100)
#show
#plot_fem_mesh(df_x_y["x"].values, df_x_y["y"].values, df_elements.values)

plt.colorbar()
plt.axis('equal')
plt.show()

# %% [markdown]
# <h1> Rectangle domain (small cell 0.0008 straight)

# %%
df_x_y = pd.read_csv("./domains/domain_2/mesh00008_s/mesh_nodes.csv")
df_z = pd.read_csv("./output/domain_2/mesh0008_s/Test_domain_2_rectangle_00008_s_solution.csv")
df_elements = pd.read_csv("./domains/domain_2/mesh00008_s/mesh_polygons.csv")
for element in df_elements.values:
    element -= 1;

triangulation = tri.Triangulation(df_x_y["x"].values, df_x_y["y"].values, triangles=df_elements.values)
plt.tricontourf(triangulation, df_z["sol"].values, levels = 100)
#show
#plot_fem_mesh(df_x_y["x"].values, df_x_y["y"].values, df_elements.values)

plt.colorbar()
plt.axis('equal')
plt.show()
