# %%
import matplotlib.pyplot as plt
import matplotlib.tri as tri
import pandas as pd
import numpy as np



# plots a finite element mesh
def plot_fem_mesh(nodes_x, nodes_y, elements, linewidth: float = 0.2):
    # print(nodes_x)
    it = 0
    for element in elements:
        x = [nodes_x[element[0]], nodes_x[element[1]], nodes_x[element[2]]]
        y = [nodes_y[element[0]], nodes_y[element[1]], nodes_y[element[2]]]
        # print(x , y)
        plt.fill(x, y, edgecolor='black', linewidth = linewidth, fill=False)
        it += 1

# %% [markdown]
# <h1> Big cells (0.1)

# %%
df_x_y = pd.read_csv("./domains/domain_1/mesh01/mesh_nodes.csv")
df_z = pd.read_csv("./output/domain_1/mesh01/Test_domain_1_sin_mesh_01_solution.csv")
df_elements = pd.read_csv("./domains/domain_1/mesh01/mesh_polygons.csv")
for element in df_elements.values:
    element -= 1;

triangulation = tri.Triangulation(df_x_y["x"].values, df_x_y["y"].values, triangles=df_elements.values)
plt.tricontourf(triangulation, df_z["sol"].values)
# show
plot_fem_mesh(df_x_y["x"].values, df_x_y["y"].values, df_elements.values)

plt.colorbar()
plt.axis('equal')
plt.show()

# %% [markdown]
# <h1> Normal cells (0.05)

# %%
df_x_y = pd.read_csv("./domains/domain_1/mesh005/mesh_nodes.csv")
df_z = pd.read_csv("./output/domain_1/mesh005/Test_domain_1_sin_mesh_005_solution.csv")
df_elements = pd.read_csv("./domains/domain_1/mesh005/mesh_polygons.csv")
for element in df_elements.values:
    element -= 1;

triangulation = tri.Triangulation(df_x_y["x"].values, df_x_y["y"].values, triangles=df_elements.values)
plt.tricontourf(triangulation, df_z["sol"].values, levels = 15)
# show
#plot_fem_mesh(df_x_y["x"].values, df_x_y["y"].values, df_elements.values)

plt.colorbar()
plt.axis('equal')
plt.show()

# %% [markdown]
# <h1> Small cells (0.01)

# %%
df_x_y = pd.read_csv("./domains/domain_1/mesh001/mesh_nodes.csv")
df_z = pd.read_csv("./output/domain_1/mesh001/Test_domain_1_sin_mesh_001_solution.csv")
df_elements = pd.read_csv("./domains/domain_1/mesh001/mesh_polygons.csv")
for element in df_elements.values:
    element -= 1;

df_z_1 = pd.read_csv("./output/domain_1/mesh001_1/Test_domain_1_sin_mesh_001_solution.csv")



triangulation = tri.Triangulation(df_x_y["x"].values, df_x_y["y"].values, triangles=df_elements.values)
plt.tricontourf(triangulation, df_z_1["sol"].values, levels=25)
# show
#plot_fem_mesh(df_x_y["x"].values, df_x_y["y"].values, df_elements.values)

plt.colorbar()
plt.axis('equal')
plt.show()

print(np.mean(np.fabs(df_z["sol"].values - df_z_1["sol"].values)))
# Out:
# 0.24743915093026708

# %%
df_x_y = pd.read_csv("./domains/domain_1/mesh001/mesh_nodes.csv")
df_z = pd.read_csv("./output/domain_1/mesh001_1/Test_domain_1_sin_mesh_001_solution.csv")
df_elements = pd.read_csv("./domains/domain_1/mesh001/mesh_polygons.csv")
for element in df_elements.values:
    element -= 1;


triangulation = tri.Triangulation(df_x_y["x"].values, df_x_y["y"].values, triangles=df_elements.values)
plt.tricontourf(triangulation, df_z["sol"].values, levels=25)
# show
#plot_fem_mesh(df_x_y["x"].values, df_x_y["y"].values, df_elements.values)

plt.colorbar()
plt.axis('equal')
plt.show()

# %%
df_x_y = pd.read_csv("./domains/domain_1/mesh001/mesh_nodes.csv")
df_z = pd.read_csv("./output/domain_1/mesh001_1/Test_domain_1_sin_mesh_001_solution.csv")
df_elements = pd.read_csv("./domains/domain_1/mesh001/mesh_polygons.csv")
for element in df_elements.values:
    element -= 1;



nodes_x = df_x_y["x"].values
tmp = df_x_y["x"].values - 4
nodes_x = np.concatenate((nodes_x, tmp), axis=0)
tmp = df_x_y["x"].values + 4
nodes_x = np.concatenate((nodes_x, tmp), axis=0)

nodes_y = np.concatenate(( df_x_y["y"].values,  df_x_y["y"].values), axis=0)
nodes_y = np.concatenate(( nodes_y,  df_x_y["y"].values), axis=0)

z_val = np.concatenate(( df_z["sol"].values, df_z["sol"].values), axis=0)
z_val = np.concatenate(( z_val, df_z["sol"].values), axis=0)

k = np.max(df_elements.values) + 1
triangles = df_elements.values
triangles = np.concatenate((triangles,  df_elements.values + k ), axis=0)
triangles = np.concatenate((triangles,  df_elements.values + k + k ), axis=0)


triangulation = tri.Triangulation(nodes_x, nodes_y, triangles=triangles)
plt.tricontourf(triangulation, z_val,levels=25)
# show
#plot_fem_mesh(nodes_x, nodes_y, triangles, 0.05)

plt.colorbar()
plt.axis('equal')
plt.show()

# %% [markdown]
# <h1> Extra Small cells (0.0001)

# %%
df_x_y = pd.read_csv("./domains/domain_1/mesh0001/mesh_nodes.csv")
df_z = pd.read_csv("./output/domain_1/mesh0001/Test_domain_1_sin_mesh_0001_solution.csv")
df_elements = pd.read_csv("./domains/domain_1/mesh0001/mesh_polygons.csv")
for element in df_elements.values:
    element -= 1;

triangulation = tri.Triangulation(df_x_y["x"].values, df_x_y["y"].values, triangles=df_elements.values)
plt.tricontourf(triangulation, df_z["sol"].values, levels=100)
# show
#plot_fem_mesh(df_x_y["x"].values, df_x_y["y"].values, df_elements.values, 0.05)

plt.colorbar()
plt.axis('equal')
plt.show()

# %%
df_x_y = pd.read_csv("./domains/domain_1/mesh0001/mesh_nodes.csv")
df_z = pd.read_csv("./output/domain_1/mesh0001/Test_domain_1_sin_mesh_0001_solution.csv")
df_elements = pd.read_csv("./domains/domain_1/mesh0001/mesh_polygons.csv")
for element in df_elements.values:
    element -= 1;

triangulation = tri.Triangulation(df_x_y["x"].values, df_x_y["y"].values, triangles=df_elements.values)
plt.tricontourf(triangulation, df_z["sol"].values, levels=100)
# show
#plot_fem_mesh(df_x_y["x"].values, df_x_y["y"].values, df_elements.values, 0.05)

plt.colorbar()
plt.axis('equal')
plt.show()

# %%
df_x_y = pd.read_csv("./domains/domain_1/mesh0001/mesh_nodes.csv")
df_z = pd.read_csv("./output/domain_1/mesh0001/Test_domain_1_sin_mesh_0001_solution.csv")
df_elements = pd.read_csv("./domains/domain_1/mesh0001/mesh_polygons.csv")
for element in df_elements.values:
    element -= 1;



nodes_x = df_x_y["x"].values
tmp = df_x_y["x"].values - 4
nodes_x = np.concatenate((nodes_x, tmp), axis=0)
tmp = df_x_y["x"].values + 4
nodes_x = np.concatenate((nodes_x, tmp), axis=0)

nodes_y = np.concatenate(( df_x_y["y"].values,  df_x_y["y"].values), axis=0)
nodes_y = np.concatenate(( nodes_y,  df_x_y["y"].values), axis=0)

z_val = np.concatenate(( df_z["sol"].values, df_z["sol"].values), axis=0)
z_val = np.concatenate(( z_val, df_z["sol"].values), axis=0)

k = np.max(df_elements.values) + 1
triangles = df_elements.values
triangles = np.concatenate((triangles,  df_elements.values + k ), axis=0)
triangles = np.concatenate((triangles,  df_elements.values + k + k ), axis=0)


triangulation = tri.Triangulation(nodes_x, nodes_y, triangles=triangles)
plt.tricontourf(triangulation, z_val, levels=100)
# show
#plot_fem_mesh(nodes_x, nodes_y, triangles, 0.05)

plt.colorbar()
plt.axis('equal')
plt.show()
